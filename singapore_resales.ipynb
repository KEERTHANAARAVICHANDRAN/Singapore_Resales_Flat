# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("ResaleFlatPricesBasedonApprovalDate19901999.csv")
df2 = pd.read_csv("ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df3 = pd.read_csv("ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df4 = pd.read_csv("ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df5 = pd.read_csv("ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %%
df=pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 927042  2024-05      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 927043  2024-05      YISHUN  EXECUTIVE  355A    YISHUN RING RD     01 TO 03
# 927044  2024-05      YISHUN  EXECUTIVE   292      YISHUN ST 22     01 TO 03
# 927045  2024-05      YISHUN  EXECUTIVE   643      YISHUN ST 61     10 TO 12
# 927046  2024-05      YISHUN  EXECUTIVE   834      YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# 1                 31.0        IMPROVED                 1977        6000.0
# 2                 31.0        IMPROVED                 1977        8000.0
# 3                 31.0        IMPROVED                 1977        6000.0
# 4                 73.0  NEW GENERATION                 1976       47200.0
# ...                ...             ...                  ...           ...
# 927042           145.0       Apartment                 1988      735000.0
# 927043           146.0      Maisonette                 1988      815888.0
# 927044           169.0       Apartment                 1992     1032000.0
# 927045           142.0       Apartment                 1987      800000.0
# 927046           154.0      Maisonette                 1988      948000.0
#
#            remaining_lease
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 927042  63 years 03 months
# 927043  63 years 02 months
# 927044  67 years 02 months
# 927045  62 years 05 months
# 927046  62 years 09 months
#
# [927047 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927047 entries, 0 to 927046
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                927047 non-null  object
#  1   town                 927047 non-null  object
#  2   flat_type            927047 non-null  object
#  3   block                927047 non-null  object
#  4   street_name          927047 non-null  object
#  5   storey_range         927047 non-null  object
#  6   floor_area_sqm       927047 non-null  float64
#  7   flat_model           927047 non-null  object
#  8   lease_commence_date  927047 non-null  int64
#  9   resale_price         927047 non-null  float64
#  10  remaining_lease      217997 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.8+ MB

# %%
df.describe().T
# Out:
#                         count           mean            std     min       25%  \
# floor_area_sqm       927047.0      95.691005      25.825190    28.0      73.0
# lease_commence_date  927047.0    1988.273783      10.660283  1966.0    1981.0
# resale_price         927047.0  320711.920408  170388.657955  5000.0  193000.0
#
#                           50%       75%        max
# floor_area_sqm           93.0     113.0      307.0
# lease_commence_date    1986.0    1996.0     2022.0
# resale_price         297000.0  418000.0  1568888.0

# %%
# checking the unique values in flat_type feature
df['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              352318
# 3 ROOM              295964
# 5 ROOM              195422
# EXECUTIVE            69669
# 2 ROOM               11827
# 1 ROOM                1304
# MULTI GENERATION       279
# MULTI-GENERATION       264
# Name: count, dtype: int64

# %%
# checking the unique values in town feature
df['town'].value_counts()
# Out:
# town
# TAMPINES           79968
# YISHUN             70061
# JURONG WEST        66689
# BEDOK              66663
# WOODLANDS          65536
# ANG MO KIO         52074
# HOUGANG            50749
# BUKIT BATOK        44407
# CHOA CHU KANG      38323
# BUKIT MERAH        34366
# PASIR RIS          33229
# SENGKANG           32465
# TOA PAYOH          31523
# QUEENSTOWN         28774
# GEYLANG            28167
# CLEMENTI           28030
# BUKIT PANJANG      27695
# KALLANG/WHAMPOA    27182
# JURONG EAST        24789
# SERANGOON          22825
# BISHAN             21263
# PUNGGOL            20641
# SEMBAWANG          13862
# MARINE PARADE       8041
# CENTRAL AREA        7145
# BUKIT TIMAH         2516
# LIM CHU KANG          64
# Name: count, dtype: int64

# %%
df['storey_range'].value_counts()
# Out:
# storey_range
# 04 TO 06    232621
# 07 TO 09    210165
# 01 TO 03    186390
# 10 TO 12    178820
# 13 TO 15     62013
# 16 TO 18     24155
# 19 TO 21     11429
# 22 TO 24      7436
# 25 TO 27      3440
# 01 TO 05      2700
# 06 TO 10      2474
# 28 TO 30      1645
# 11 TO 15      1259
# 31 TO 33       630
# 34 TO 36       577
# 37 TO 39       508
# 16 TO 20       265
# 40 TO 42       246
# 21 TO 25        92
# 43 TO 45        65
# 46 TO 48        52
# 26 TO 30        39
# 49 TO 51        17
# 36 TO 40         7
# 31 TO 35         2
# Name: count, dtype: int64

# %%
df['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   194730
# Improved                  168216
# New Generation            110077
# NEW GENERATION             78898
# IMPROVED                   73589
# MODEL A                    70381
# Premium Apartment          46766
# Simplified                 34287
# Apartment                  25588
# Standard                   25165
# SIMPLIFIED                 23258
# Maisonette                 17449
# STANDARD                   17375
# MAISONETTE                 12215
# Model A2                   10139
# APARTMENT                   9901
# DBSS                        3305
# Adjoined flat               1249
# Model A-Maisonette          1095
# MODEL A-MAISONETTE           982
# Terrace                      447
# Type S1                      436
# MULTI GENERATION             279
# Multi Generation             264
# TERRACE                      247
# Type S2                      217
# 2-room                       113
# Premium Apartment Loft       108
# Premium Maisonette            86
# Improved-Maisonette           82
# IMPROVED-MAISONETTE           44
# 3Gen                          32
# 2-ROOM                        21
# PREMIUM APARTMENT              6
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease'],
#       dtype='object')

# %%
# Convert the 'month' column to a datetime format
df['month'] = pd.to_datetime(df['month'])

# Extract the year and month into separate columns
df['year'] = df['month'].dt.year
df['month_of_year'] = df['month'].dt.month
df
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1990-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...           ...         ...        ...   ...               ...          ...
# 927042 2024-05-01      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 927043 2024-05-01      YISHUN  EXECUTIVE  355A    YISHUN RING RD     01 TO 03
# 927044 2024-05-01      YISHUN  EXECUTIVE   292      YISHUN ST 22     01 TO 03
# 927045 2024-05-01      YISHUN  EXECUTIVE   643      YISHUN ST 61     10 TO 12
# 927046 2024-05-01      YISHUN  EXECUTIVE   834      YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# 1                 31.0        IMPROVED                 1977        6000.0
# 2                 31.0        IMPROVED                 1977        8000.0
# 3                 31.0        IMPROVED                 1977        6000.0
# 4                 73.0  NEW GENERATION                 1976       47200.0
# ...                ...             ...                  ...           ...
# 927042           145.0       Apartment                 1988      735000.0
# 927043           146.0      Maisonette                 1988      815888.0
# 927044           169.0       Apartment                 1992     1032000.0
# 927045           142.0       Apartment                 1987      800000.0
# 927046           154.0      Maisonette                 1988      948000.0
#
#            remaining_lease  year  month_of_year
# 0                      NaN  1990              1
# 1                      NaN  1990              1
# 2                      NaN  1990              1
# 3                      NaN  1990              1
# 4                      NaN  1990              1
# ...                    ...   ...            ...
# 927042  63 years 03 months  2024              5
# 927043  63 years 02 months  2024              5
# 927044  67 years 02 months  2024              5
# 927045  62 years 05 months  2024              5
# 927046  62 years 09 months  2024              5
#
# [927047 rows x 13 columns]

# %%
df.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# remaining_lease                object
# year                            int32
# month_of_year                   int32
# dtype: object

# %%
df['lease_commence_year'] = pd.to_datetime(df['lease_commence_date'],format = '%Y').dt.year
# Extract the year of lease commencement
#df['lease_commence_year'] = df['lease_commence_date'].dt.year

# %%
df
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1990-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...           ...         ...        ...   ...               ...          ...
# 927042 2024-05-01      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 927043 2024-05-01      YISHUN  EXECUTIVE  355A    YISHUN RING RD     01 TO 03
# 927044 2024-05-01      YISHUN  EXECUTIVE   292      YISHUN ST 22     01 TO 03
# 927045 2024-05-01      YISHUN  EXECUTIVE   643      YISHUN ST 61     10 TO 12
# 927046 2024-05-01      YISHUN  EXECUTIVE   834      YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# 1                 31.0        IMPROVED                 1977        6000.0
# 2                 31.0        IMPROVED                 1977        8000.0
# 3                 31.0        IMPROVED                 1977        6000.0
# 4                 73.0  NEW GENERATION                 1976       47200.0
# ...                ...             ...                  ...           ...
# 927042           145.0       Apartment                 1988      735000.0
# 927043           146.0      Maisonette                 1988      815888.0
# 927044           169.0       Apartment                 1992     1032000.0
# 927045           142.0       Apartment                 1987      800000.0
# 927046           154.0      Maisonette                 1988      948000.0
#
#            remaining_lease  year  month_of_year  lease_commence_year
# 0                      NaN  1990              1                 1977
# 1                      NaN  1990              1                 1977
# 2                      NaN  1990              1                 1977
# 3                      NaN  1990              1                 1977
# 4                      NaN  1990              1                 1976
# ...                    ...   ...            ...                  ...
# 927042  63 years 03 months  2024              5                 1988
# 927043  63 years 02 months  2024              5                 1988
# 927044  67 years 02 months  2024              5                 1992
# 927045  62 years 05 months  2024              5                 1987
# 927046  62 years 09 months  2024              5                 1988
#
# [927047 rows x 14 columns]

# %%
df.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# remaining_lease                object
# year                            int32
# month_of_year                   int32
# lease_commence_year             int32
# dtype: object

# %%
# Extract the remaining_lease feature

data = df['remaining_lease']
house_new = pd.DataFrame(data)

# Extract years and months using regular expressions
lease_info = df['remaining_lease'].str.extract(r'(\d+) years (\d+) months')
lease_info.columns = ['years', 'months']

# Convert to numeric values
df['remaining_lease_years'] = pd.to_numeric(lease_info['years'])
df['remaining_lease_months'] = pd.to_numeric(lease_info['months'])

# %%
df_new_data = df.copy()

# %%
df_new_data
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1990-01-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1990-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...           ...         ...        ...   ...               ...          ...
# 927042 2024-05-01      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 927043 2024-05-01      YISHUN  EXECUTIVE  355A    YISHUN RING RD     01 TO 03
# 927044 2024-05-01      YISHUN  EXECUTIVE   292      YISHUN ST 22     01 TO 03
# 927045 2024-05-01      YISHUN  EXECUTIVE   643      YISHUN ST 61     10 TO 12
# 927046 2024-05-01      YISHUN  EXECUTIVE   834      YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# 1                 31.0        IMPROVED                 1977        6000.0
# 2                 31.0        IMPROVED                 1977        8000.0
# 3                 31.0        IMPROVED                 1977        6000.0
# 4                 73.0  NEW GENERATION                 1976       47200.0
# ...                ...             ...                  ...           ...
# 927042           145.0       Apartment                 1988      735000.0
# 927043           146.0      Maisonette                 1988      815888.0
# 927044           169.0       Apartment                 1992     1032000.0
# 927045           142.0       Apartment                 1987      800000.0
# 927046           154.0      Maisonette                 1988      948000.0
#
#            remaining_lease  year  month_of_year  lease_commence_year  \
# 0                      NaN  1990              1                 1977
# 1                      NaN  1990              1                 1977
# 2                      NaN  1990              1                 1977
# 3                      NaN  1990              1                 1977
# 4                      NaN  1990              1                 1976
# ...                    ...   ...            ...                  ...
# 927042  63 years 03 months  2024              5                 1988
# 927043  63 years 02 months  2024              5                 1988
# 927044  67 years 02 months  2024              5                 1992
# 927045  62 years 05 months  2024              5                 1987
# 927046  62 years 09 months  2024              5                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ...                       ...                     ...
# 927042                   63.0                     3.0
# 927043                   63.0                     2.0
# 927044                   67.0                     2.0
# 927045                   62.0                     5.0
# 927046                   62.0                     9.0
#
# [927047 rows x 16 columns]

# %%
df_new_data.isnull().sum()
# Out:
# month                          0
# town                           0
# flat_type                      0
# block                          0
# street_name                    0
# storey_range                   0
# floor_area_sqm                 0
# flat_model                     0
# lease_commence_date            0
# resale_price                   0
# remaining_lease           709050
# year                           0
# month_of_year                  0
# lease_commence_year            0
# remaining_lease_years     775772
# remaining_lease_months    775772
# dtype: int64

# %%
# handleing the null values using mean method
df_new_data['remaining_lease_years'].fillna(df['remaining_lease_years'].mean(),inplace = True)
df_new_data['remaining_lease_months'].fillna(df['remaining_lease_months'].mean(),inplace = True)
df_new_data.isnull().sum()
# Out:
# C:\Users\Anupama\AppData\Local\Temp\ipykernel_17264\1547425854.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new_data['remaining_lease_years'].fillna(df['remaining_lease_years'].mean(),inplace = True)
# C:\Users\Anupama\AppData\Local\Temp\ipykernel_17264\1547425854.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new_data['remaining_lease_months'].fillna(df['remaining_lease_months'].mean(),inplace = True)
# month                          0
# town                           0
# flat_type                      0
# block                          0
# street_name                    0
# storey_range                   0
# floor_area_sqm                 0
# flat_model                     0
# lease_commence_date            0
# resale_price                   0
# remaining_lease           709050
# year                           0
# month_of_year                  0
# lease_commence_year            0
# remaining_lease_years          0
# remaining_lease_months         0
# dtype: int64

# %%
#  dropping the existing features 
df_new_data.drop(columns=['month','lease_commence_date','remaining_lease'],inplace = True)
df_new_data
# Out:
#               town  flat_type block       street_name storey_range  \
# 0       ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...            ...        ...   ...               ...          ...
# 927042      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 927043      YISHUN  EXECUTIVE  355A    YISHUN RING RD     01 TO 03
# 927044      YISHUN  EXECUTIVE   292      YISHUN ST 22     01 TO 03
# 927045      YISHUN  EXECUTIVE   643      YISHUN ST 61     10 TO 12
# 927046      YISHUN  EXECUTIVE   834      YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  resale_price  year  month_of_year  \
# 0                 31.0        IMPROVED        9000.0  1990              1
# 1                 31.0        IMPROVED        6000.0  1990              1
# 2                 31.0        IMPROVED        8000.0  1990              1
# 3                 31.0        IMPROVED        6000.0  1990              1
# 4                 73.0  NEW GENERATION       47200.0  1990              1
# ...                ...             ...           ...   ...            ...
# 927042           145.0       Apartment      735000.0  2024              5
# 927043           146.0      Maisonette      815888.0  2024              5
# 927044           169.0       Apartment     1032000.0  2024              5
# 927045           142.0       Apartment      800000.0  2024              5
# 927046           154.0      Maisonette      948000.0  2024              5
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1977              74.038539                6.533591
# 1                      1977              74.038539                6.533591
# 2                      1977              74.038539                6.533591
# 3                      1977              74.038539                6.533591
# 4                      1976              74.038539                6.533591
# ...                     ...                    ...                     ...
# 927042                 1988              63.000000                3.000000
# 927043                 1988              63.000000                2.000000
# 927044                 1992              67.000000                2.000000
# 927045                 1987              62.000000                5.000000
# 927046                 1988              62.000000                9.000000
#
# [927047 rows x 13 columns]

# %%
# DATA PREPROCESSING
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_new_data['town'] = encoder.fit_transform(df_new_data['town'])
df_new_data['flat_type'] = encoder.fit_transform(df_new_data['flat_type'])
df_new_data['storey_range'] = encoder.fit_transform(df_new_data['storey_range'])
df_new_data['flat_model'] = encoder.fit_transform(df_new_data['flat_model'])

# %%
df_new_data
# Out:
#         town  flat_type block       street_name  storey_range  floor_area_sqm  \
# 0          0          0   309  ANG MO KIO AVE 1             5            31.0
# 1          0          0   309  ANG MO KIO AVE 1             2            31.0
# 2          0          0   309  ANG MO KIO AVE 1             5            31.0
# 3          0          0   309  ANG MO KIO AVE 1             4            31.0
# 4          0          2   216  ANG MO KIO AVE 1             2            73.0
# ...      ...        ...   ...               ...           ...             ...
# 927042    26          5   360    YISHUN RING RD             2           145.0
# 927043    26          5  355A    YISHUN RING RD             0           146.0
# 927044    26          5   292      YISHUN ST 22             0           169.0
# 927045    26          5   643      YISHUN ST 61             5           142.0
# 927046    26          5   834      YISHUN ST 81             2           154.0
#
#         flat_model  resale_price  year  month_of_year  lease_commence_year  \
# 0                7        9000.0  1990              1                 1977
# 1                7        6000.0  1990              1                 1977
# 2                7        8000.0  1990              1                 1977
# 3                7        6000.0  1990              1                 1977
# 4               20       47200.0  1990              1                 1976
# ...            ...           ...   ...            ...                  ...
# 927042           5      735000.0  2024              5                 1988
# 927043          15      815888.0  2024              5                 1988
# 927044           5     1032000.0  2024              5                 1992
# 927045           5      800000.0  2024              5                 1987
# 927046          15      948000.0  2024              5                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.038539                6.533591
# 1                   74.038539                6.533591
# 2                   74.038539                6.533591
# 3                   74.038539                6.533591
# 4                   74.038539                6.533591
# ...                       ...                     ...
# 927042              63.000000                3.000000
# 927043              63.000000                2.000000
# 927044              67.000000                2.000000
# 927045              62.000000                5.000000
# 927046              62.000000                9.000000
#
# [927047 rows x 13 columns]

# %%
df_new_data.describe().T
# Out:
#                            count           mean            std     min  \
# town                    927047.0      13.652928       8.795713     0.0
# flat_type               927047.0       3.014156       0.949430     0.0
# storey_range            927047.0       3.409603       2.663844     0.0
# floor_area_sqm          927047.0      95.691005      25.825190    28.0
# flat_model              927047.0      15.714570       6.667707     0.0
# resale_price            927047.0  320711.920408  170388.657955  5000.0
# year                    927047.0    2006.166353       9.319180  1990.0
# month_of_year           927047.0       6.550717       3.413794     1.0
# lease_commence_year     927047.0    1988.273783      10.660283  1966.0
# remaining_lease_years   927047.0      74.038539       5.624679    41.0
# remaining_lease_months  927047.0       6.533591       1.166688     0.0
#
#                                   25%            50%            75%        max
# town                         5.000000      13.000000      23.000000       26.0
# flat_type                    2.000000       3.000000       4.000000        7.0
# storey_range                 2.000000       4.000000       5.000000       24.0
# floor_area_sqm              73.000000      93.000000     113.000000      307.0
# flat_model                   9.000000      16.000000      21.000000       33.0
# resale_price            193000.000000  297000.000000  418000.000000  1568888.0
# year                      1999.000000    2005.000000    2014.000000     2024.0
# month_of_year                4.000000       7.000000      10.000000       12.0
# lease_commence_year       1981.000000    1986.000000    1996.000000     2022.0
# remaining_lease_years       74.038539      74.038539      74.038539       97.0
# remaining_lease_months       6.533591       6.533591       6.533591       11.0

# %%
# Skewness Handling
# checking the outliars using boxplot distribution plot

def plot(df_new_data,column):
    plt.figure(figsize =(15,6))
    plt.subplot(1,3,1)
    sns.boxplot(data = df_new_data ,x = column)
    plt.title(f'box plot for {column}')
    

    plt.subplot(1,3,2)
    sns.histplot(data = df_new_data ,x = column,kde = True ,bins = 40)
    plt.title(f'distribution  plot for {column}')
    plt.show()

# %%
for i in ['floor_area_sqm','resale_price','lease_commence_year','remaining_lease_years']:
    plot(df_new_data ,i)

# %%
# 'floor_area_sqm','resale_price' this two feature are skewd in data handling log method 


df_new_data['floor_area_sqm'] = np.log(df_new_data['floor_area_sqm'])
df_new_data['resale_price'] = np.log(df_new_data['resale_price'])
df_new_data
# Out:
#         town  flat_type block       street_name  storey_range  floor_area_sqm  \
# 0          0          0   309  ANG MO KIO AVE 1             5        3.433987
# 1          0          0   309  ANG MO KIO AVE 1             2        3.433987
# 2          0          0   309  ANG MO KIO AVE 1             5        3.433987
# 3          0          0   309  ANG MO KIO AVE 1             4        3.433987
# 4          0          2   216  ANG MO KIO AVE 1             2        4.290459
# ...      ...        ...   ...               ...           ...             ...
# 927042    26          5   360    YISHUN RING RD             2        4.976734
# 927043    26          5  355A    YISHUN RING RD             0        4.983607
# 927044    26          5   292      YISHUN ST 22             0        5.129899
# 927045    26          5   643      YISHUN ST 61             5        4.955827
# 927046    26          5   834      YISHUN ST 81             2        5.036953
#
#         flat_model  resale_price  year  month_of_year  lease_commence_year  \
# 0                7      9.104980  1990              1                 1977
# 1                7      8.699515  1990              1                 1977
# 2                7      8.987197  1990              1                 1977
# 3                7      8.699515  1990              1                 1977
# 4               20     10.762149  1990              1                 1976
# ...            ...           ...   ...            ...                  ...
# 927042           5     13.507626  2024              5                 1988
# 927043          15     13.612032  2024              5                 1988
# 927044           5     13.847009  2024              5                 1992
# 927045           5     13.592367  2024              5                 1987
# 927046          15     13.762110  2024              5                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.038539                6.533591
# 1                   74.038539                6.533591
# 2                   74.038539                6.533591
# 3                   74.038539                6.533591
# 4                   74.038539                6.533591
# ...                       ...                     ...
# 927042              63.000000                3.000000
# 927043              63.000000                2.000000
# 927044              67.000000                2.000000
# 927045              62.000000                5.000000
# 927046              62.000000                9.000000
#
# [927047 rows x 13 columns]

# %%
for i in ['floor_area_sqm','resale_price']:
    plot(df_new_data,i)

# %%
# Treat Outliers using IQR
#using the IQR & Clips  method removing the outliars :
# formula IQR = Q3_Q1
def outlier(df_new_data ,column):
    IQR = df_new_data[column].quantile(0.75)-df_new_data[column].quantile(0.25)
    upper_value = df_new_data[column].quantile(0.75)+1.5*IQR
    lower_value = df_new_data[column].quantile(0.25)-1.5*IQR
    
    df_new_data[column] =     df_new_data[column].clip(upper_value,lower_value)

outlier(df_new_data, 'floor_area_sqm')
outlier(df_new_data, 'resale_price')
df_new_data1 = df_new_data.copy()

# %%
df_new_data1
# Out:
#         town  flat_type block       street_name  storey_range  floor_area_sqm  \
# 0          0          0   309  ANG MO KIO AVE 1             5        3.635067
# 1          0          0   309  ANG MO KIO AVE 1             2        3.635067
# 2          0          0   309  ANG MO KIO AVE 1             5        3.635067
# 3          0          0   309  ANG MO KIO AVE 1             4        3.635067
# 4          0          2   216  ANG MO KIO AVE 1             2        4.290459
# ...      ...        ...   ...               ...           ...             ...
# 927042    26          5   360    YISHUN RING RD             2        4.976734
# 927043    26          5  355A    YISHUN RING RD             0        4.983607
# 927044    26          5   292      YISHUN ST 22             0        5.129899
# 927045    26          5   643      YISHUN ST 61             5        4.955827
# 927046    26          5   834      YISHUN ST 81             2        5.036953
#
#         flat_model  resale_price  year  month_of_year  lease_commence_year  \
# 0                7     11.011259  1990              1                 1977
# 1                7     11.011259  1990              1                 1977
# 2                7     11.011259  1990              1                 1977
# 3                7     11.011259  1990              1                 1977
# 4               20     11.011259  1990              1                 1976
# ...            ...           ...   ...            ...                  ...
# 927042           5     13.507626  2024              5                 1988
# 927043          15     13.612032  2024              5                 1988
# 927044           5     13.847009  2024              5                 1992
# 927045           5     13.592367  2024              5                 1987
# 927046          15     13.762110  2024              5                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.038539                6.533591
# 1                   74.038539                6.533591
# 2                   74.038539                6.533591
# 3                   74.038539                6.533591
# 4                   74.038539                6.533591
# ...                       ...                     ...
# 927042              63.000000                3.000000
# 927043              63.000000                2.000000
# 927044              67.000000                2.000000
# 927045              62.000000                5.000000
# 927046              62.000000                9.000000
#
# [927047 rows x 13 columns]

# %%
# after IQR using checking the skewness
for i in ['floor_area_sqm','resale_price']:
    plot(df_new_data1,i)

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_model', x= 'resale_price',data = df )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_model'>

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'town', x= 'resale_price',data = df )
# Out:
# <Axes: xlabel='resale_price', ylabel='town'>

# %%
# Basic EDA
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_type', x= 'resale_price',data = df )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_type'>

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'resale_price' ,y = 'floor_area_sqm',data = df)
# Out:
# <Axes: xlabel='resale_price', ylabel='floor_area_sqm'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'lease_commence_year' , y = 'resale_price', data = df_new_data)
# Out:
# <Axes: xlabel='lease_commence_year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'year', y = 'resale_price', data = df_new_data)
# Out:
# <Axes: xlabel='year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'remaining_lease_years' , y = 'resale_price', data = df_new_data)
# Out:
# <Axes: xlabel='remaining_lease_years', ylabel='resale_price'>

# %%
# dropping the irrelvent feature 
df_new_data1.drop(columns=['block','street_name'],inplace = True)
df_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 0          0          0             5        3.635067           7
# 1          0          0             2        3.635067           7
# 2          0          0             5        3.635067           7
# 3          0          0             4        3.635067           7
# 4          0          2             2        4.290459          20
# ...      ...        ...           ...             ...         ...
# 927042    26          5             2        4.976734           5
# 927043    26          5             0        4.983607          15
# 927044    26          5             0        5.129899           5
# 927045    26          5             5        4.955827           5
# 927046    26          5             2        5.036953          15
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 0          11.011259  1990              1                 1977
# 1          11.011259  1990              1                 1977
# 2          11.011259  1990              1                 1977
# 3          11.011259  1990              1                 1977
# 4          11.011259  1990              1                 1976
# ...              ...   ...            ...                  ...
# 927042     13.507626  2024              5                 1988
# 927043     13.612032  2024              5                 1988
# 927044     13.847009  2024              5                 1992
# 927045     13.592367  2024              5                 1987
# 927046     13.762110  2024              5                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.038539                6.533591
# 1                   74.038539                6.533591
# 2                   74.038539                6.533591
# 3                   74.038539                6.533591
# 4                   74.038539                6.533591
# ...                       ...                     ...
# 927042              63.000000                3.000000
# 927043              63.000000                2.000000
# 927044              67.000000                2.000000
# 927045              62.000000                5.000000
# 927046              62.000000                9.000000
#
# [927047 rows x 11 columns]

# %%
df_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 0          0          0             5        3.635067           7
# 1          0          0             2        3.635067           7
# 2          0          0             5        3.635067           7
# 3          0          0             4        3.635067           7
# 4          0          2             2        4.290459          20
# ...      ...        ...           ...             ...         ...
# 927042    26          5             2        4.976734           5
# 927043    26          5             0        4.983607          15
# 927044    26          5             0        5.129899           5
# 927045    26          5             5        4.955827           5
# 927046    26          5             2        5.036953          15
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 0          11.011259  1990              1                 1977
# 1          11.011259  1990              1                 1977
# 2          11.011259  1990              1                 1977
# 3          11.011259  1990              1                 1977
# 4          11.011259  1990              1                 1976
# ...              ...   ...            ...                  ...
# 927042     13.507626  2024              5                 1988
# 927043     13.612032  2024              5                 1988
# 927044     13.847009  2024              5                 1992
# 927045     13.592367  2024              5                 1987
# 927046     13.762110  2024              5                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.038539                6.533591
# 1                   74.038539                6.533591
# 2                   74.038539                6.533591
# 3                   74.038539                6.533591
# 4                   74.038539                6.533591
# ...                       ...                     ...
# 927042              63.000000                3.000000
# 927043              63.000000                2.000000
# 927044              67.000000                2.000000
# 927045              62.000000                5.000000
# 927046              62.000000                9.000000
#
# [927047 rows x 11 columns]

# %%
df_new_data1.dtypes
# Out:
# town                        int32
# flat_type                   int32
# storey_range                int32
# floor_area_sqm            float64
# flat_model                  int32
# resale_price              float64
# year                        int32
# month_of_year               int32
# lease_commence_year         int32
# remaining_lease_years     float64
# remaining_lease_months    float64
# dtype: object

# %%
heat =df_new_data1.corr()
heat
# Out:
#                             town  flat_type  storey_range  floor_area_sqm  \
# town                    1.000000   0.137084     -0.047899        0.136230
# flat_type               0.137084   1.000000      0.074647        0.940932
# storey_range           -0.047899   0.074647      1.000000        0.049804
# floor_area_sqm          0.136230   0.940932      0.049804        1.000000
# flat_model             -0.102691  -0.360012     -0.068403       -0.363060
# resale_price            0.084160   0.602483      0.186735        0.599595
# year                    0.072358   0.101638      0.104691        0.075941
# month_of_year           0.003052   0.003495     -0.002710        0.003131
# lease_commence_year     0.213762   0.408564      0.166605        0.422199
# remaining_lease_years   0.083846   0.072768      0.133233        0.060491
# remaining_lease_months  0.002200  -0.000774     -0.000692       -0.001381
#
#                         flat_model  resale_price      year  month_of_year  \
# town                     -0.102691      0.084160  0.072358       0.003052
# flat_type                -0.360012      0.602483  0.101638       0.003495
# storey_range             -0.068403      0.186735  0.104691      -0.002710
# floor_area_sqm           -0.363060      0.599595  0.075941       0.003131
# flat_model                1.000000     -0.181130  0.063222      -0.004979
# resale_price             -0.181130      1.000000  0.688453       0.009805
# year                      0.063222      0.688453  1.000000      -0.025937
# month_of_year            -0.004979      0.009805 -0.025937       1.000000
# lease_commence_year      -0.118135      0.534332  0.431349       0.003499
# remaining_lease_years    -0.030207      0.084784 -0.001598      -0.003436
# remaining_lease_months    0.000536      0.001206  0.000666       0.007503
#
#                         lease_commence_year  remaining_lease_years  \
# town                               0.213762               0.083846
# flat_type                          0.408564               0.072768
# storey_range                       0.166605               0.133233
# floor_area_sqm                     0.422199               0.060491
# flat_model                        -0.118135              -0.030207
# resale_price                       0.534332               0.084784
# year                               0.431349              -0.001598
# month_of_year                      0.003499              -0.003436
# lease_commence_year                1.000000               0.524705
# remaining_lease_years              0.524705               1.000000
# remaining_lease_months             0.008847              -0.002286
#
#                         remaining_lease_months
# town                                  0.002200
# flat_type                            -0.000774
# storey_range                         -0.000692
# floor_area_sqm                       -0.001381
# flat_model                            0.000536
# resale_price                          0.001206
# year                                  0.000666
# month_of_year                         0.007503
# lease_commence_year                   0.008847
# remaining_lease_years                -0.002286
# remaining_lease_months                1.000000

# %%
# Need to verify any columns are highly correlated using Heatmap
plt.figure(figsize=(15,6))
sns.heatmap(heat,annot = True)
# Out:
# <Axes: >

# %%
# Model Buliding:
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model   import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import pickle

# %%
df_new_data1.columns
# Out:
# Index(['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'resale_price', 'year', 'month_of_year', 'lease_commence_year',
#        'remaining_lease_years', 'remaining_lease_months'],
#       dtype='object')

# %%
x = df_new_data1[['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
        'year', 'month_of_year', 'lease_commence_year',
       'remaining_lease_years', 'remaining_lease_months']]
y = df_new_data1[['resale_price']]

# %%
#standardize the features of a dataset
encoder = StandardScaler()

encoder.fit_transform(x)
# Out:
# array([[-1.55222605e+00, -3.17470218e+00,  5.97031353e-01, ...,
#         -1.05755068e+00,  1.51591182e-14,  7.61282490e-16],
#        [-1.55222605e+00, -3.17470218e+00, -5.29161526e-01, ...,
#         -1.05755068e+00,  1.51591182e-14,  7.61282490e-16],
#        [-1.55222605e+00, -3.17470218e+00,  5.97031353e-01, ...,
#         -1.05755068e+00,  1.51591182e-14,  7.61282490e-16],
#        ...,
#        [ 1.40376091e+00,  2.09161863e+00, -1.27995678e+00, ...,
#          3.49542198e-01, -1.25136792e+00, -3.88586738e+00],
#        [ 1.40376091e+00,  2.09161863e+00,  5.97031353e-01, ...,
#         -1.19488762e-01, -2.14030801e+00, -1.31448373e+00],
#        [ 1.40376091e+00,  2.09161863e+00, -5.29161526e-01, ...,
#         -2.56825701e-02, -2.14030801e+00,  2.11402781e+00]])

# %%
#check the accuracy of training and testing using metrics RandomForestRegressor


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

RFR= RandomForestRegressor(n_estimators= 50 ,random_state = 0)

# fitting the model: 

RFR.fit(x_train,y_train)

y_pred_train = RFR.predict(x_train)
y_pred_test = RFR.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9959410818192875, 0.9810991195535378)

# %%
# we got good accuracy after oversampling
# RandomForestRegressor have good testing accuracy, but in training accuracy is overfitting.
# GridsearchCV is a cross validation function
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

param = {'max_depth'        : [20],
              'min_samples_split': [ 5, ],
              'min_samples_leaf' : [ 2, ],
              'max_features'     : ['log2']}
grid_searchcv = GridSearchCV(RandomForestRegressor(),param_grid = param,  cv = 5)
grid_searchcv.fit(x_train, y_train)
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [20], 'max_features': ['log2'],
#                          'min_samples_leaf': [2], 'min_samples_split': [5]})

# %%
grid_searchcv.best_score_
# Out:
# 0.9746094980438305

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9810591635890953, 0.9750326492405242)

# %%
# now the training accuracy overfitting reduced. so now model will predict effectively for unseen data
# predict the selling price with hypertuning parameters and calculate the accuracy using metrics

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)                      
print('Mean Squared Error:' ,mean_squared_error(y_test,y_pred_test))
print('Mean Absolute Error:',mean_absolute_error(y_test,y_pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred_test)))
print(r2_score(y_test,y_pred_test))
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean Squared Error: 0.008319189001957336
# Mean Absolute Error: 0.06659029605244425
# Root Mean Squared Error: 0.0912095883224858
# 0.9750900954236605

# %%
#  manually passed the user input and predict the selling price

user_data = np.array([[0,1,3,3.785069,5,2017,1,1979,61.000000,4.000000]])
y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 12.33663193176375

# %%
user_data = np.array([[4,3,2,4.785069,4,2023,3,1989,69.000000,4.000000]])

y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 13.465708983008215

# %%
# using Inverse Log Transformation to convert the value to original re sale price of the data (exp)
np.exp(y_prediction[0])
# Out:
# 704827.931357463

# %%
#  save the regression model by using pickle

with open(r"Flat_price_model.pkl", 'wb') as f:
    pickle.dump(Hyper_model, f)

# %%
#  load the model
with open("Flat_price_model.pkl", 'rb') as f:
    model = pickle.load(f)

user_data = np.array([[4, 3, 2, 4.785069, 4, 2023, 3, 1989, 69.000000, 4.000000]])
prediction = model.predict(user_data)
predicted_price = prediction[0]
predicted_price
np.exp(predicted_price)
# Out:
# d:\test\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 704827.931357463
